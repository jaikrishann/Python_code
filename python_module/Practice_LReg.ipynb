# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('laptopPrice.csv')
df.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 1    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 2    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 3  512 GB     0 GB  Windows  32-bit            2 GB  Casual  No warranty
# 4    0 GB   512 GB  Windows  64-bit            0 GB  Casual  No warranty
#
#   Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 818    False
# 819    False
# 820    False
# 821    False
# 822    False
# Length: 823, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 21

# %%
df = df.drop_duplicates()
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
cat_col = df.select_dtypes(include='O')
cat_col.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 1    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 2    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 3  512 GB     0 GB  Windows  32-bit            2 GB  Casual  No warranty
# 4    0 GB   512 GB  Windows  64-bit            0 GB  Casual  No warranty
#
#   Touchscreen msoffice   rating
# 0          No       No  2 stars
# ...

# %%
num_col = df.select_dtypes(exclude='O')
num_col
# Out:
#       Price  Number of Ratings  Number of Reviews
# 0     34649                  3                  0
# 1     38999                 65                  5
# 2     39999                  8                  1
# 3     69990                  0                  0
# 4     26990                  0                  0
# ..      ...                ...                ...
# 818  135990                  0                  0
# 819  144990                  0                  0
# 820  149990                  0                  0
# 821  142990                  0                  0
# 822   57490                 18                  4
#
# [802 rows x 3 columns]

# %%
cat_col = cat_col.drop(['weight','msoffice','warranty','Touchscreen'],axis='columns')
cat_col
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb   rating
# ...

# %%
cat_col['ram_type'].nunique()
# Out:
# 6

# %%
cat_col.isnull().sum()
# Out:
# brand              0
# processor_brand    0
# processor_name     0
# processor_gnrtn    0
# ram_gb             0
# ram_type           0
# ssd                0
# hdd                0
# os                 0
# os_bit             0
# graphic_card_gb    0
# rating             0
# dtype: int64

# %%
cat_col.fillna(0, inplace=True)

# %%
cat_col
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb   rating
# ...

# %%
df2 = pd.read_csv('Diamonds Prices2022.csv')
df2
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
# 53940       53941   0.71    Premium     E     SI1   60.5   55.0   2756  5.79
# 53941       53942   0.71    Premium     F     SI1   59.8   62.0   2756  5.74
# 53942       53943   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71
#
#           y     z
# 0      3.98  2.43
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53943 entries, 0 to 53942
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53943 non-null  int64
#  1   carat       53943 non-null  float64
#  2   cut         53943 non-null  object
#  3   color       53943 non-null  object
#  4   clarity     53943 non-null  object
#  5   depth       53943 non-null  float64
#  6   table       53943 non-null  float64
#  7   price       53943 non-null  int64
#  8   x           53943 non-null  float64
#  9   y           53943 non-null  float64
#  10  z           53943 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
cat_col1 = df2.select_dtypes(include='O')
cat_col1
# Out:
#              cut color clarity
# 0          Ideal     E     SI2
# 1        Premium     E     SI1
# 2           Good     E     VS1
# 3        Premium     I     VS2
# 4           Good     J     SI2
# ...          ...   ...     ...
# 53938    Premium     H     SI2
# 53939      Ideal     D     SI2
# 53940    Premium     E     SI1
# 53941    Premium     F     SI1
# 53942  Very Good     E     VS2
#
# [53943 rows x 3 columns]

# %%
num_col1 = df2.select_dtypes(exclude='O')
num_col1
# Out:
#        Unnamed: 0  carat  depth  table  price     x     y     z
# 0               1   0.23   61.5   55.0    326  3.95  3.98  2.43
# 1               2   0.21   59.8   61.0    326  3.89  3.84  2.31
# 2               3   0.23   56.9   65.0    327  4.05  4.07  2.31
# 3               4   0.29   62.4   58.0    334  4.20  4.23  2.63
# 4               5   0.31   63.3   58.0    335  4.34  4.35  2.75
# ...           ...    ...    ...    ...    ...   ...   ...   ...
# 53938       53939   0.86   61.0   58.0   2757  6.15  6.12  3.74
# 53939       53940   0.75   62.2   55.0   2757  5.83  5.87  3.64
# 53940       53941   0.71   60.5   55.0   2756  5.79  5.74  3.49
# 53941       53942   0.71   59.8   62.0   2756  5.74  5.73  3.43
# 53942       53943   0.70   60.5   59.0   2757  5.71  5.76  3.47
#
# [53943 rows x 8 columns]

# %%
cat_col1['cut'].value_counts()
# Out:
# cut
# Ideal        21551
# Premium      13793
# Very Good    12083
# Good          4906
# Fair          1610
# Name: count, dtype: int64

# %%
cat_col1['color'].value_counts()
# Out:
# color
# G    11292
# E     9799
# F     9543
# H     8304
# D     6775
# I     5422
# J     2808
# Name: count, dtype: int64

# %%
import shutil

print("hell i am from i\\\\\\\\\\\\\\\\\\\\\\\\\\\\\ttarget")
# Out:
# hell i am from i	arget

# %%
shutil.move("laptopPrice.csv",r"C:\Users\Jai\Desktop\laptopPrice.csv")
# Out:
# 'C:\\Users\\Jai\\Desktop\\laptopPrice.csv'

# %%
cat_col1['clarity'].value_counts()
# Out:
# clarity
# SI1     13067
# VS2     12259
# SI2      9194
# VS1      8171
# VVS2     5066
# VVS1     3655
# IF       1790
# I1        741
# Name: count, dtype: int64

# %%
dt = {"Ideal":1,"Premium":2,"Very Good":3,"Good":4,"Fair":5}
dt
# Out:
# {'Ideal': 1, 'Premium': 2, 'Very Good': 3, 'Good': 4, 'Fair': 5}

# %%
cat_col1['cut'] = cat_col1['cut'].map(dt)

# %%
cat_col1['cut'].value_counts()
# Out:
# cut
# 1    21551
# 2    13793
# 3    12083
# 4     4906
# 5     1610
# Name: count, dtype: int64

# %%
{i:key for key , i in enumerate(list(cat_col1['clarity'].unique()))}
# Out:
# {'SI2': 0,
#  'SI1': 1,
#  'VS1': 2,
#  'VS2': 3,
#  'VVS2': 4,
#  'VVS1': 5,
#  'I1': 6,
#  'IF': 7}

# %%
dt2 = {'SI2': 0,
 'SI1': 1,
 'VS1': 2,
 'VS2': 3,
 'VVS2': 4,
 'VVS1': 5,
 'I1': 6,
 'IF': 7}

# %%
cat_col1['clarity'] = cat_col1['clarity'].map(dt2)

# %%
dt3 = {'D':0,'E':2,'F':3,'G':4,'H':5,'I':6,'J':7}

# %%
cat_col1['color']=cat_col1['color'].map(dt3)

# %%
cat_col1
# Out:
#        cut  color  clarity
# 0        1      2        0
# 1        2      2        1
# 2        4      2        2
# 3        2      6        3
# 4        4      7        0
# ...    ...    ...      ...
# 53938    2      5        0
# 53939    1      0        0
# 53940    2      2        1
# 53941    2      3        1
# 53942    3      2        3
#
# [53943 rows x 3 columns]

# %%
num_col1
# Out:
#        Unnamed: 0  carat  depth  table  price     x     y     z
# 0               1   0.23   61.5   55.0    326  3.95  3.98  2.43
# 1               2   0.21   59.8   61.0    326  3.89  3.84  2.31
# 2               3   0.23   56.9   65.0    327  4.05  4.07  2.31
# 3               4   0.29   62.4   58.0    334  4.20  4.23  2.63
# 4               5   0.31   63.3   58.0    335  4.34  4.35  2.75
# ...           ...    ...    ...    ...    ...   ...   ...   ...
# 53938       53939   0.86   61.0   58.0   2757  6.15  6.12  3.74
# 53939       53940   0.75   62.2   55.0   2757  5.83  5.87  3.64
# 53940       53941   0.71   60.5   55.0   2756  5.79  5.74  3.49
# 53941       53942   0.71   59.8   62.0   2756  5.74  5.73  3.43
# 53942       53943   0.70   60.5   59.0   2757  5.71  5.76  3.47
#
# [53943 rows x 8 columns]

# %%
complete_df = pd.concat([cat_col1,num_col1],axis=1)
complete_df=complete_df.drop(['Unnamed: 0','x','y','z'],axis='columns')
complete_df
# Out:
#        cut  color  clarity  carat  depth  table  price
# 0        1      2        0   0.23   61.5   55.0    326
# 1        2      2        1   0.21   59.8   61.0    326
# 2        4      2        2   0.23   56.9   65.0    327
# 3        2      6        3   0.29   62.4   58.0    334
# 4        4      7        0   0.31   63.3   58.0    335
# ...    ...    ...      ...    ...    ...    ...    ...
# 53938    2      5        0   0.86   61.0   58.0   2757
# 53939    1      0        0   0.75   62.2   55.0   2757
# 53940    2      2        1   0.71   60.5   55.0   2756
# 53941    2      3        1   0.71   59.8   62.0   2756
# 53942    3      2        3   0.70   60.5   59.0   2757
#
# [53943 rows x 7 columns]

# %%
complete_df.dtypes
# Out:
# cut          int64
# color        int64
# clarity      int64
# carat      float64
# depth      float64
# table      float64
# price        int64
# dtype: object

# %%
metrix = complete_df.corr()
metrix
# Out:
#               cut     color   clarity     carat     depth     table     price
# cut      1.000000  0.019616 -0.141123  0.134964  0.218037  0.433387  0.053487
# color    0.019616  1.000000  0.033342  0.278734  0.044448  0.025089  0.166062
# clarity -0.141123  0.033342  1.000000 -0.281211 -0.025853 -0.133690 -0.140262
# carat    0.134964  0.278734 -0.281211  1.000000  0.028234  0.181602  0.921591
# depth    0.218037  0.044448 -0.025853  0.028234  1.000000 -0.295798 -0.010630
# table    0.433387  0.025089 -0.133690  0.181602 -0.295798  1.000000  0.127118
# price    0.053487  0.166062 -0.140262  0.921591 -0.010630  0.127118  1.000000

# %%
plt.figure(figsize=(8,8))
sns.heatmap(metrix,annot=True)
plt.show()

# %%
x = complete_df.drop('price',axis=1)
y = complete_df[['price']]

# %%
x.shape
# Out:
# (53943, 6)

# %%
from sklearn.model_selection import train_test_split

# %%
df2.shape
# Out:
# (53943, 11)

# %%
x_train,x_test ,y_train,y_test = train_test_split(x,y,test_size=0.4,random_state=42)

# %%
x_train
# Out:
#        cut  color  clarity  carat  depth  table
# 15931    2      4        4   1.01   61.9   58.0
# 49175    2      7        0   0.80   61.4   57.0
# 25478    2      3        3   1.51   60.4   59.0
# 15568    2      3        3   1.01   62.3   58.0
# 14089    1      3        0   1.23   62.8   57.0
# ...    ...    ...      ...    ...    ...    ...
# 11284    3      6        3   1.05   62.4   59.0
# 44732    1      0        2   0.47   61.0   55.0
# 38158    3      3        7   0.33   60.3   58.0
# 860      2      7        1   0.90   62.8   59.0
# 15795    2      3        1   1.14   60.4   58.0
#
# [32365 rows x 6 columns]

# %%
y_test.shape
# Out:
# (21578, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train,y_train)
# Out:
# 0.8821245880403591

# %%
lr.score(x_test,y_test)
# Out:
# 0.8791654588541193

# %%
sns.pairplot(df2)

# %%
#linear fashion
# Polynomial regression it transform data from non linear fashion to linear fashion

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
pred = lr.predict(x_test)

# %%
y_test['prediction'] = pred

# %%
lr.score(x_test,y_test['price'])
# Out:
# 0.8791654588541193

# %%
r2_score(y_test['price'],y_test['prediction'])
# Out:
# 0.8791654588541193

# %%
mean_squared_error(y_test['price'],y_test['prediction'])
# Out:
# 1896495.9770977322

# %%
# adjusted r squared
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures()

# %%
x_train_transformed = poly.fit_transform(x_train)

# %%
x_test_transformed = poly.fit_transform(x_test)

# %%
lr2 = LinearRegression()

# %%
lr2.fit(x_train_transformed,y_train)
# Out:
# LinearRegression()

# %%
lr2.score(x_train_transformed,y_train)
# Out:
# 0.907857761152945

# %%
lr2.score(x_test_transformed,y_test['price'])
# Out:
# 0.904777306731122

# %%
from sklearn.preprocessing import StandardScaler
# mean = 0 
# standard deviation = 1

# %%
df["Price"].std()
# Out:
# 45232.98442159339
