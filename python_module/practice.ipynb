# %%
import pandas as pd

# %%
df = pd.read_csv('annual-enterprise-survey-2021-financial-year-provisional-csv.csv')
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
# 1. ktm data -- sort by highest price(top 10), 
# 2 ya toh brand ho ktm ya brand RE (filter(or),RE min price and ktm min price, then tell which bike is available at lowest price) make a function
# 3 find out avg price of first owner bikes 
# 4 find out all the bikes price sum who has age is 3

# %%
df = pd.read_csv('Used_Bikes.csv')
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
KTM_data = df[(df['brand'])=='KTM']
KTM_data
# Out:
#               bike_name     price        city  kms_driven         owner  age  \
# 33         KTM RC 390cc  180000.0        Pune     17700.0   First Owner  4.0
# 35       KTM Duke 200cc   70000.0      Nashik    100000.0  Second Owner  8.0
# 39     KTM RC 200cc ABS  179000.0   Bangalore      3400.0   First Owner  2.0
# 65       KTM Duke 200cc   94700.0    Baripara     32700.0   First Owner  4.0
# 83       KTM Duke 250cc  130000.0  Gandhidham     17500.0  Second Owner  4.0
# ...                 ...       ...         ...         ...           ...  ...
# 32541      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
# 32560      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
# 32579      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
# 32598      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
# 32636      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
#
#        power brand
# 33     390.0   KTM
# ...

# %%
# 1. ktm data -- sort by highest price(top 10), 

Ktm_top20=KTM_data.sort_values(by='price',ascending=False).head(21)
Ktm_top20
# Out:
#            bike_name     price         city  kms_driven         owner  age  \
# 8197  KTM Duke 200cc  860000.0        Delhi     12000.0  Second Owner  5.0
# 4834  KTM Duke 390cc  263000.0        Delhi      1178.0   First Owner  2.0
# 2522  KTM Duke 390cc  260000.0         Vapi      1500.0   First Owner  2.0
# 8606  KTM Duke 390cc  250430.0     Jabalpur      4300.0   First Owner  3.0
# 8662  KTM Duke 390cc  250430.0     Jabalpur      4300.0   First Owner  3.0
# 3508    KTM RC 390cc  250000.0  Bulandshahr      3000.0   First Owner  4.0
# 8645  KTM Duke 390cc  250000.0         Pune      2730.0   First Owner  2.0
# 5830  KTM Duke 390cc  248000.0         Pune      5300.0   First Owner  4.0
# 6178  KTM Duke 390cc  248000.0         Pune      5300.0   First Owner  4.0
# 5572  KTM Duke 390cc  243100.0        Delhi     16000.0   First Owner  3.0
# 99    KTM Duke 390cc  240000.0    Bangalore     11000.0   First Owner  3.0
# ...

# %%
# 2 ya toh brand ho ktm ya brand RE (filter(or),RE min price and ktm min price, then tell which bike is available at lowest price) make a function

RE_or_KTM = df[(df['brand']=='Royal Enfield') | (df['brand']=='KTM')] 
RE_or_KTM
# Out:
#                                       bike_name     price  \
# 1                   Royal Enfield Classic 350cc  119900.0
# 8             Royal Enfield Thunderbird X 350cc  145000.0
# 9      Royal Enfield Classic Desert Storm 500cc   88000.0
# 23           Royal Enfield Classic Chrome 500cc  121700.0
# 33                                 KTM RC 390cc  180000.0
# ...                                         ...       ...
# 32614        Royal Enfield Bullet Electra 350cc  105000.0
# 32633               Royal Enfield Classic 350cc   87000.0
# 32634           Royal Enfield Thunderbird 350cc   70000.0
# 32636                              KTM RC 390cc  196700.0
# 32639               Royal Enfield Classic 350cc   95500.0
#
#                       city  kms_driven         owner   age  power  \
# 1                    Delhi     11000.0   First Owner   4.0  350.0
# 8                Bangalore      9190.0   First Owner   3.0  350.0
# 9                    Delhi     19000.0  Second Owner   7.0  500.0
# ...

# %%
def lowest_price_bike(df):
    filtered_df = df[(df['brand'] == 'KTM') | (df['brand'] == 'Royal Enfield')]
    min_price_ktm=filtered_df[(filtered_df['brand']=='KTM')]['price'].min()
    min_price_RE=filtered_df[(filtered_df['brand']=='Royal Enfield')]['price'].min()
    result = lowest_price_bike(df)
    print(result)

# %%
# 3 find out avg price of first owner bikes 
Avg_price = df[(df['owner']=='First Owner')]['price'].mean()
Avg_price
# Out:
# 69512.4200373782

# %%
# 4 find out all the bikes price sum who has age is 3 
SUM_of_bikes_age_3 = df[(df['age']==3)]['price'].sum()
SUM_of_bikes_age_3
# Out:
# 181502364.0
