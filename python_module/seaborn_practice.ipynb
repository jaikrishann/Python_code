# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('athlete_events.csv')
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df.shape
# Out:
# (271116, 15)

# %%
df.query("Season=='Winter'")
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6            5  Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 7            5  Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 8            5  Christine Jacoba Aaftink   F  27.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                Team  NOC        Games  Year  Season            City  \
# 4       Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...

# %%
sns.lineplot(df.query("Season=='Winter'")['Height'])
plt.show()

# %%
sns.scatterplot(x='Height',y='Weight',data=df)
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>

# %%
sns.histplot(df['Weight'])
# Out:
# <Axes: xlabel='Weight', ylabel='Count'>

# %%
electric_car = pd.read_csv('ElectricCarData_Clean.csv')
electric_car
# Out:
#            Brand                            Model  AccelSec  TopSpeed_KmH  \
# 0         Tesla     Model 3 Long Range Dual Motor       4.6           233
# 1    Volkswagen                         ID.3 Pure      10.0           160
# 2      Polestar                                 2       4.7           210
# 3           BMW                              iX3        6.8           180
# 4         Honda                                e        9.5           145
# ..           ...                              ...       ...           ...
# 98       Nissan                       Ariya 63kWh       7.5           160
# 99         Audi     e-tron S Sportback 55 quattro       4.5           210
# 100      Nissan               Ariya e-4ORCE 63kWh       5.9           200
# 101      Nissan   Ariya e-4ORCE 87kWh Performance       5.1           200
# 102       Byton                 M-Byte 95 kWh 2WD       7.5           190
#
#      Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# ...

# %%
sns.lineplot(electric_car['Range_Km'])
# Out:
# <Axes: ylabel='Range_Km'>

# %%
sns.histplot(electric_car['TopSpeed_KmH'])
# Out:
# <Axes: xlabel='TopSpeed_KmH', ylabel='Count'>

# %%
sns.scatterplot(x='Range_Km', y= 'TopSpeed_KmH', data= electric_car)
# Out:
# <Axes: xlabel='Range_Km', ylabel='TopSpeed_KmH'>

# %%
sns.kdeplot(electric_car['Range_Km'])
# Out:
# <Axes: xlabel='Range_Km', ylabel='Density'>

# %%
electric_car
# Out:
#            Brand                            Model  AccelSec  TopSpeed_KmH  \
# 0         Tesla     Model 3 Long Range Dual Motor       4.6           233
# 1    Volkswagen                         ID.3 Pure      10.0           160
# 2      Polestar                                 2       4.7           210
# 3           BMW                              iX3        6.8           180
# 4         Honda                                e        9.5           145
# ..           ...                              ...       ...           ...
# 98       Nissan                       Ariya 63kWh       7.5           160
# 99         Audi     e-tron S Sportback 55 quattro       4.5           210
# 100      Nissan               Ariya e-4ORCE 63kWh       5.9           200
# 101      Nissan   Ariya e-4ORCE 87kWh Performance       5.1           200
# 102       Byton                 M-Byte 95 kWh 2WD       7.5           190
#
#      Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# ...

# %%
sns.relplot(x='TopSpeed_KmH',y='Range_Km',data=electric_car,kind='scatter')

# %%
sns.relplot(x='TopSpeed_KmH',y='Range_Km',data=electric_car,kind='line')

# %%
sns.relplot(x='TopSpeed_KmH',y='Range_Km',data=electric_car,kind='scatter',hue='PriceEuro')

# %%
sns.relplot(x='TopSpeed_KmH',y='Range_Km',data=electric_car,kind='scatter',hue='PriceEuro',style='RapidCharge')

# %%
sns.relplot(x='TopSpeed_KmH',y='Range_Km',data=electric_car,kind='scatter',hue='PriceEuro',style='RapidCharge',row='Segment')

# %%
sns.relplot(x='TopSpeed_KmH',y='Range_Km',data=electric_car,kind='scatter',hue='PriceEuro',style='RapidCharge',col='RapidCharge')

# %%
electric_car
# Out:
#            Brand                            Model  AccelSec  TopSpeed_KmH  \
# 0         Tesla     Model 3 Long Range Dual Motor       4.6           233
# 1    Volkswagen                         ID.3 Pure      10.0           160
# 2      Polestar                                 2       4.7           210
# 3           BMW                              iX3        6.8           180
# 4         Honda                                e        9.5           145
# ..           ...                              ...       ...           ...
# 98       Nissan                       Ariya 63kWh       7.5           160
# 99         Audi     e-tron S Sportback 55 quattro       4.5           210
# 100      Nissan               Ariya e-4ORCE 63kWh       5.9           200
# 101      Nissan   Ariya e-4ORCE 87kWh Performance       5.1           200
# 102       Byton                 M-Byte 95 kWh 2WD       7.5           190
#
#      Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# ...

# %%
sns.catplot(x='BodyStyle',y='AccelSec',data=electric_car,kind='strip')

# %%
sns.catplot(x='BodyStyle',y='AccelSec',data=electric_car,kind='swarm')
# Out:
# c:\Users\Jai\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 6.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x='BodyStyle',y='AccelSec',data=electric_car,kind='bar')
plt.xticks(rotation=60)
plt.show()

# %%
# univariet analysis
# bivariet 2 columns
# multivariet

# %%
sns.catplot(x='BodyStyle',y='AccelSec',data=electric_car,kind='box')
plt.xticks(rotation=60)
plt.show()
