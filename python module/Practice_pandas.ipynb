# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('laptopPrice.csv')
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df['brand']
# Out:
# 0        ASUS
# 1      Lenovo
# 2      Lenovo
# 3        ASUS
# 4        ASUS
#         ...
# 818      ASUS
# 819      ASUS
# 820      ASUS
# 821      ASUS
# 822    Lenovo
# Name: brand, Length: 823, dtype: object

# %%
df['processor_brand']
# Out:
# 0      Intel
# 1      Intel
# 2      Intel
# 3      Intel
# 4      Intel
#        ...
# 818      AMD
# 819      AMD
# 820      AMD
# 821      AMD
# 822      AMD
# Name: processor_brand, Length: 823, dtype: object

# %%
df.dtypes
# Out:
# brand                object
# processor_brand      object
# processor_name       object
# processor_gnrtn      object
# ram_gb               object
# ram_type             object
# ssd                  object
# hdd                  object
# os                   object
# os_bit               object
# graphic_card_gb      object
# weight               object
# warranty             object
# Touchscreen          object
# msoffice             object
# Price                 int64
# rating               object
# Number of Ratings     int64
# Number of Reviews     int64
# dtype: object

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df[['brand','ram_type','Price']]
# Out:
#       brand ram_type   Price
# 0      ASUS     DDR4   34649
# 1    Lenovo     DDR4   38999
# 2    Lenovo     DDR4   39999
# 3      ASUS     DDR4   69990
# 4      ASUS     DDR4   26990
# ..      ...      ...     ...
# 818    ASUS     DDR4  135990
# 819    ASUS     DDR4  144990
# 820    ASUS     DDR4  149990
# 821    ASUS     DDR4  142990
# 822  Lenovo     DDR4   57490
#
# [823 rows x 3 columns]

# %%
df[['processor_name','ram_gb','os_bit']]
# Out:
#     processor_name ram_gb  os_bit
# 0          Core i3   4 GB  64-bit
# 1          Core i3   4 GB  64-bit
# 2          Core i3   4 GB  64-bit
# 3          Core i5   8 GB  32-bit
# 4     Celeron Dual   4 GB  64-bit
# ..             ...    ...     ...
# 818        Ryzen 9   4 GB  64-bit
# 819        Ryzen 9   4 GB  64-bit
# 820        Ryzen 9   4 GB  64-bit
# 821        Ryzen 9   4 GB  64-bit
# 822        Ryzen 5   8 GB  64-bit
#
# [823 rows x 3 columns]

# %%
# slicing
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df[0:3]
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
#
#     ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0  0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 1  0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 2  0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
#
#   Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# 0          No       No  34649  2 stars                  3                  0
# 1          No       No  38999  3 stars                 65                  5
# 2          No       No  39999  3 stars                  8                  1

# %%
df.loc[0:10,['brand','Price']]
# Out:
#      brand  Price
# 0     ASUS  34649
# 1   Lenovo  38999
# 2   Lenovo  39999
# 3     ASUS  69990
# 4     ASUS  26990
# 5     ASUS  22990
# 6     ASUS  21990
# 7     ASUS  58799
# 8   Lenovo  49999
# 9     acer  59990
# 10    acer  93700

# %%
df.iloc[0:6,0:4]
# Out:
#     brand processor_brand processor_name processor_gnrtn
# 0    ASUS           Intel        Core i3            10th
# 1  Lenovo           Intel        Core i3            10th
# 2  Lenovo           Intel        Core i3            10th
# 3    ASUS           Intel        Core i5            10th
# 4    ASUS           Intel   Celeron Dual   Not Available
# 5    ASUS           Intel   Celeron Dual   Not Available

# %%
df['Price'].min()
# Out:
# 16990

# %%
df.min()
# Out:
# brand                       APPLE
# processor_brand               AMD
# processor_name       Celeron Dual
# processor_gnrtn              10th
# ram_gb                      16 GB
# ram_type                     DDR3
# ssd                          0 GB
# hdd                          0 GB
# os                            DOS
# os_bit                     32-bit
# graphic_card_gb              0 GB
# weight                     Casual
# warranty                   1 year
# Touchscreen                    No
# msoffice                       No
# Price                       16990
# rating                     1 star
# Number of Ratings               0
# Number of Reviews               0
# dtype: object

# %%
df['processor_name'].unique()
# Out:
# array(['Core i3', 'Core i5', 'Celeron Dual', 'Ryzen 5', 'Core i7',
#        'Core i9', 'M1', 'Pentium Quad', 'Ryzen 3', 'Ryzen 7', 'Ryzen 9'],
#       dtype=object)

# %%
df['processor_brand'].value_counts()
# Out:
# processor_brand
# Intel    610
# AMD      189
# M1        24
# Name: count, dtype: int64

# %%
df['processor_name'].value_counts()
# Out:
# processor_name
# Core i5         290
# Core i3         164
# Core i7         110
# Ryzen 5          82
# Ryzen 7          56
# Ryzen 3          26
# Ryzen 9          26
# Celeron Dual     24
# M1               24
# Pentium Quad     13
# Core i9           8
# Name: count, dtype: int64

# %%
df['processor_name'].nunique()
# Out:
# 11

# %%
df.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 1    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 2    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 3  512 GB     0 GB  Windows  32-bit            2 GB  Casual  No warranty
# 4    0 GB   512 GB  Windows  64-bit            0 GB  Casual  No warranty
#
#   Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# ...

# %%
df.tail()
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd   hdd       os  os_bit graphic_card_gb      weight     warranty  \
# 818  1024 GB  0 GB  Windows  64-bit            0 GB      Casual       1 year
# 819  1024 GB  0 GB  Windows  64-bit            0 GB      Casual       1 year
# 820  1024 GB  0 GB  Windows  64-bit            4 GB      Casual       1 year
# 821  1024 GB  0 GB  Windows  64-bit            4 GB      Casual       1 year
# 822   512 GB  0 GB      DOS  64-bit            0 GB  ThinNlight  No warranty
#
# ...

# %%
df.head(10)
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 6    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 7    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 8  Lenovo           Intel        Core i5            10th   4 GB     DDR4
# 9    acer             AMD        Ryzen 5            10th   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# ...

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
Intel = df[df['processor_brand']=='Intel']
Intel
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 632    ASUS           Intel   Pentium Quad   Not Available   4 GB   LPDDR4
# 633    ASUS           Intel   Pentium Quad   Not Available   4 GB     DDR4
# 634    ASUS           Intel   Pentium Quad   Not Available   4 GB     DDR4
# 635    ASUS           Intel   Pentium Quad   Not Available   4 GB     DDR4
# 750  Lenovo           Intel        Ryzen 7   Not Available   4 GB     DDR4
#
# ...

# %%
Intel['processor_name'].value_counts()
# Out:
# processor_name
# Core i5         290
# Core i3         164
# Core i7         110
# Celeron Dual     24
# Pentium Quad     13
# Core i9           8
# Ryzen 7           1
# Name: count, dtype: int64

# %%
cel_dual_pro=Intel[Intel['processor_name']=='Celeron Dual']
cel_dual_pro
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 6      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 12    Avita           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 13     ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 17   Lenovo           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 18       HP           Intel   Celeron Dual   Not Available   8 GB     DDR4
# 19   Lenovo           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 20     ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 21     ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 64     acer           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ...

# %%
Intel
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 632    ASUS           Intel   Pentium Quad   Not Available   4 GB   LPDDR4
# 633    ASUS           Intel   Pentium Quad   Not Available   4 GB     DDR4
# 634    ASUS           Intel   Pentium Quad   Not Available   4 GB     DDR4
# 635    ASUS           Intel   Pentium Quad   Not Available   4 GB     DDR4
# 750  Lenovo           Intel        Ryzen 7   Not Available   4 GB     DDR4
#
# ...

# %%
price_50k=Intel[Intel['Price']<=50000]
price_50k
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 631    DELL           Intel   Pentium Quad   Not Available   4 GB     DDR4
# 632    ASUS           Intel   Pentium Quad   Not Available   4 GB   LPDDR4
# 633    ASUS           Intel   Pentium Quad   Not Available   4 GB     DDR4
# 634    ASUS           Intel   Pentium Quad   Not Available   4 GB     DDR4
# 635    ASUS           Intel   Pentium Quad   Not Available   4 GB     DDR4
#
# ...

# %%
price_50k['brand'].value_counts()
# Out:
# brand
# ASUS      74
# DELL      50
# Lenovo    38
# HP        31
# acer       7
# MSI        3
# Avita      2
# Name: count, dtype: int64

# %%
dell_brand=price_50k[price_50k['brand']=='DELL']
dell_brand
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 29   DELL           Intel        Core i3            10th   8 GB     DDR4
# 36   DELL           Intel        Core i3            11th   8 GB     DDR4
# 39   DELL           Intel        Core i3            11th   8 GB     DDR4
# 40   DELL           Intel        Core i3            10th   4 GB     DDR4
# 44   DELL           Intel        Core i3            10th   4 GB     DDR4
# 47   DELL           Intel        Core i3            11th   8 GB     DDR4
# 48   DELL           Intel        Core i3            11th   8 GB     DDR4
# 49   DELL           Intel        Core i3            11th   8 GB     DDR4
# 50   DELL           Intel        Core i3            11th   8 GB     DDR4
# 59   DELL           Intel        Core i3            11th   4 GB     DDR4
# 63   DELL           Intel        Core i3            10th   4 GB     DDR4
# 76   DELL           Intel        Core i3            11th   4 GB     DDR4
# ...

# %%
dell_brand['Price'].mean()
# Out:
# 42948.52

# %%
avg_dell_price=dell_brand[dell_brand['Price']<=42948.52]
avg_dell_price
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 29   DELL           Intel        Core i3            10th   8 GB     DDR4
# 36   DELL           Intel        Core i3            11th   8 GB     DDR4
# 39   DELL           Intel        Core i3            11th   8 GB     DDR4
# 40   DELL           Intel        Core i3            10th   4 GB     DDR4
# 44   DELL           Intel        Core i3            10th   4 GB     DDR4
# 49   DELL           Intel        Core i3            11th   8 GB     DDR4
# 50   DELL           Intel        Core i3            11th   8 GB     DDR4
# 63   DELL           Intel        Core i3            10th   4 GB     DDR4
# 79   DELL           Intel        Core i3            10th   4 GB     DDR4
# 110  DELL           Intel        Core i3            10th   8 GB     DDR4
# 126  DELL           Intel        Core i3            10th   4 GB     DDR4
# 132  DELL           Intel        Core i3            11th   8 GB     DDR4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
# ...

# %%
avg_dell_price['processor_name'].unique()
# Out:
# array(['Core i3', 'Pentium Quad'], dtype=object)

# %%
df.duplicated().sum()
# Out:
# 21

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.isnull().sum()
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64
